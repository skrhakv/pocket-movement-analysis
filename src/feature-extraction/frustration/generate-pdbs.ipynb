# %%
import json
import biotite.structure.io.pdbx as pdbx
import biotite.structure.io.pdb as pdb
import biotite.structure as struc
from biotite.sequence import ProteinSequence
import os
import numpy as np

DATASET = 'rigid-dataset'
DATASET_PATH = f'../../../datasets/{DATASET}/folds'

def load_apo_structures(path):
    with open(path) as f:
        dataset = json.load(f)
    
    ids = {}
    for apo_id, holo_structures in dataset.items():
        for holo_structure in holo_structures:
            # skip multichain structures
            if '-' in holo_structure['apo_chain']:
                continue
            id = apo_id + holo_structure['apo_chain']
            if id in ids: ids[id].update(holo_structure['apo_pocket_selection'])
            else: ids[id] = set([int(''.join(filter(str.isdigit, residue.split('_')[1]))) for residue in holo_structure['apo_pocket_selection']])
    return ids

ids = {}
for fold in [f'train-fold-{i}.json' for i in range(4)]:
    subset_ids = load_apo_structures(f'{DATASET_PATH}/{fold}')
    ids = {**ids, **subset_ids}

CIF_FILES_PATH = '/home/vit/Projects/deeplife-project/data/cif_files'
OUTPUT_PATH = 'modified-pdbs'
FLUCTUATION_INPUT_PATH = f'../../../data/features/fluctuation/{DATASET}/fluctuation'
SKIPPED_IDS = ['5x6zD', '4ok2B', '5h61B', '1fl1B', '8hynA', '1sh0A', '2yx7A', '6lgyA', '4gu8H', '8j1kA', '1xhxB', '1pfzC', '4omgA', '1g24C', '6j35B', '6ialF', '4j2pA', '4x1oA', '5ytbC',
               '1havA', '4ekfA', '8iy0B', '3l28F', '2xc1A', '7wyoB', '3cbjA', '1of3B', '7gosB', '7poqA', '6spoA', '2wetA', '6tyoB', '7d48A', '2zf3F', '1mwkA', '5mf2D', '7oapEEE', '8dufA',
               '4pvrA', '4gf1B', '4u0mB', '1xt3B', '6ro0G', '3sebA', '3rmyD', '6twoAAA', '1nokA', '7oumC']


for id in ids.keys():
    if id in SKIPPED_IDS: continue
    if f'{id}.pdb' in os.listdir(OUTPUT_PATH):
        continue
    print(f'Processing {id} ...')
    # read file
    mmcif_filename = f'{id[:4]}.cif'
    mmcif_file = pdbx.CIFFile.read(f'{CIF_FILES_PATH}/{mmcif_filename}')
    chain_id = id[4:]

    # load file to biotite object
    whole_structure = pdbx.get_structure(mmcif_file, model=1, include_bonds=True)
    protein = whole_structure[struc.filter_amino_acids(whole_structure)]

    # some errors with MSE residue
    # WARNING: Here I am keeping all the atoms (i.e. not keeping only C-alpha atoms)
    filtered_protein_structure = protein[(protein.chain_id == chain_id) 
                       & (
                             (protein.res_name == 'ALA')
                           | (protein.res_name == 'ARG')
                           | (protein.res_name == 'ASN')
                           | (protein.res_name == 'ASP')
                           | (protein.res_name == 'CYS')
                           | (protein.res_name == 'GLN')
                           | (protein.res_name == 'GLU')
                           | (protein.res_name == 'GLY')
                           | (protein.res_name == 'HIS')
                           | (protein.res_name == 'ILE')
                           | (protein.res_name == 'LEU')
                           | (protein.res_name == 'LYS')
                           | (protein.res_name == 'MET')
                           | (protein.res_name == 'PHE')
                           | (protein.res_name == 'PRO')
                           | (protein.res_name == 'SER')
                           | (protein.res_name == 'THR')
                           | (protein.res_name == 'TRP')
                           | (protein.res_name == 'TYR')
                           | (protein.res_name == 'VAL'))]

    # Shorten chain_id to one character if it is longer than one character
    if len(chain_id) > 1:
        filtered_protein_structure.set_annotation('chain_id', np.array([chain_id[0] for _ in range(len(filtered_protein_structure))]))

    modified_pdb_file = pdb.PDBFile()
    modified_pdb_file.set_structure(filtered_protein_structure) 
    modified_pdb_file.write(os.path.join(OUTPUT_PATH, f"{id}.pdb"))
# Out:
# Processing 7o0aB ...
# Processing 5klcA ...
# Processing 1ci8B ...
# Processing 4dwqA ...
# Processing 2y8nA ...
# Processing 6n2hA ...
# Processing 6zu2CCC ...
# Processing 4q71B ...
# Processing 6zu3A ...
# Processing 4txhD ...
# Processing 1hn0A ...
# Processing 6pkhA ...
# Processing 1j0hB ...
# Processing 5z0uA ...
# Processing 1mwoA ...
# Processing 3wdqA ...
# Processing 7atrA ...
# Processing 4dm1A ...
# Processing 1tvnA ...
# Processing 3b9eA ...
# Processing 5e3pA ...
# Processing 8vr6A ...
# Processing 6etzA ...
# Processing 2de6B ...
# Processing 1slbB ...
# Processing 6q4xA ...
# Processing 7zajAAA ...
# Processing 5kdnA ...
# Processing 3donA ...
# Processing 3jyoA ...
# Processing 6k0mA ...
# Processing 4ckqA ...
# Processing 6ir4A ...
# Processing 1iiwA ...
# Processing 4ppvA ...
# Processing 7xgvA ...
# Processing 3ex9A ...
# Processing 4crqA ...
# Processing 7ofeA ...
# Processing 3gbtA ...
# Processing 2o70D ...
# Processing 3gd0A ...
# Processing 7vtkA ...
# Processing 5jbdA ...
# Processing 5u8eA ...
# Processing 2vnsA ...
# Processing 4piqA ...
# Processing 1wd3A ...
# Processing 2cl2A ...
# Processing 7togA ...
# Processing 2b0tA ...
# Processing 3kajB ...
# Processing 2oh6A ...
# Processing 1wohA ...
# Processing 1y2tA ...
# Processing 5c7lO ...
# Processing 3u55A ...
# Processing 3bcfA ...
# Processing 2j1vB ...
# Processing 2vtfB ...
# Processing 4ff3B ...
# Processing 3pmeA ...
# Processing 5z5hA ...
# Processing 2exhC ...
# Processing 2qysA ...
# Processing 5rkzA ...
# Processing 8besA ...
# Processing 3lxzD ...
# Processing 1w9sB ...
# Processing 7qxkA ...
# Processing 8ceiC ...
# Processing 6kplA ...
# Processing 7xfuA ...
# Processing 1pmjX ...
# Processing 1zedA ...
# Processing 2dq6A ...
# Processing 5zieB ...
# Processing 3k9eA ...
# Processing 2v78A ...
# Processing 4lbgA ...
# Processing 1hjsA ...
# Processing 3appA ...
# Processing 4s3eA ...
# Processing 5d9oA ...
# Processing 6niwD ...
# Processing 3zz1A ...
# Processing 7yo7A ...
# Processing 7eapA ...
# Processing 4zoeB ...
# Processing 7zeqX ...
# Processing 1pu6B ...
# Processing 7b7qA ...
# Processing 7bfmA ...
# Processing 1n40A ...
# Processing 1ujbA ...
# Processing 5x0jA ...
# Processing 7q0oA ...
# Processing 6xy7AAA ...
# Processing 2ehzA ...
# Processing 4rehA ...
# Processing 1znwA ...
# Processing 4le7A ...
# Processing 6eeuA ...
# Processing 6d2cA ...
# Processing 3rufA ...
# Processing 4gzqA ...
# Processing 1r6yA ...
# Processing 2yglB ...
# Processing 5unnB ...
# Processing 4twmA ...
# Processing 5y1dA ...
# Processing 5qoqA ...
# Processing 1tr9A ...
# Processing 6eepA ...
# Processing 6uayA ...
# Processing 6uavA ...
# Processing 6ub3B ...
# Processing 3ugjA ...
# Processing 5whvA ...
# Processing 1ltmA ...
# Processing 7xsgA ...
# Processing 3acfA ...
# Processing 2zewB ...
# Processing 1dymA ...
# Processing 6lrfA ...
# Processing 8ev4A ...
# Processing 1kwgA ...
# Processing 2eb4E ...
# Processing 1t8tA ...
# Processing 5kjvB ...
# Processing 6yi4AAA ...
# Processing 7kd4A ...
# Processing 2qhtA ...
# Processing 7xg6A ...
# Processing 3vstC ...
# Processing 1g5aA ...
# Processing 3pyeA ...
# Processing 2z15A ...
# Processing 3p24C ...
# Processing 7p6sA ...
# Processing 5gqcF ...
# Processing 6mviA ...
# Processing 5fkqA ...
# Processing 5lsvA ...
# Processing 6imuA ...
# Processing 1cm5A ...
# Processing 1o4zB ...
# Processing 3zr5A ...
# Processing 2wsuB ...
# Processing 1hdhB ...
# Processing 4rynA ...
# Processing 5lkbB ...
# Processing 1qbaA ...
# Processing 5dgqA ...
# Processing 7c6cA ...
# Processing 1uxzA ...
# Processing 1uxzB ...
# Processing 1g9gA ...
# Processing 1dmxA ...
# Processing 3gaiA ...
# Processing 1k5cA ...
# Processing 7dfoD ...
# Processing 7vt5A ...
# Processing 4qajA ...
# Processing 2v9dA ...
# Processing 4z0zA ...
# Processing 5i6sA ...
# Processing 4ee9A ...
# Processing 7c45A ...
# Processing 4do6A ...
# Processing 3gszB ...
# Processing 3bfpA ...
# Processing 4iefB ...
# Processing 5k62A ...
# Processing 2opwA ...
# Processing 5smjB ...
# Processing 5zxgB ...
# Processing 4xslA ...
# Processing 4eb0A ...
# Processing 7vtzA ...
# Processing 3hbhA ...
# Processing 3x2mA ...
# Processing 8g95B ...
# Processing 4xzpA ...
# Processing 2eakB ...
# Processing 3a1kA ...
# Processing 3ncoA ...
# Processing 2jepA ...
# Processing 4yheB ...
# Processing 5rdhA ...
# Processing 3vmnA ...
# Processing 7yx7A ...
# Processing 6jymA ...
# Processing 5nxzA ...
# Processing 3gaqB ...
# Processing 6wcsB ...
# Processing 1gjuA ...
# Processing 5x2nA ...
# Processing 2e4uA ...
# Processing 3v9jA ...
# Processing 2bhqA ...
# Processing 7xznD ...
# Processing 1ut1C ...
# Processing 2x4lA ...
# Processing 3vvfB ...
# Processing 5wjpA ...
# Processing 2q2aD ...
# Processing 5aezA ...
# Processing 8d30B ...
# Processing 4b5nA ...
# Processing 7fhuA ...
# Processing 3g4eB ...
# Processing 4d97C ...
# Processing 4yz0B ...
# Processing 6jyrC ...
# Processing 7p1bC ...
# Processing 5hpoA ...
# Processing 4mwgA ...
# Processing 1ul9A ...
# Processing 8a24A ...
# Processing 4pzpA ...
# Processing 6m2oA ...
# Processing 6er2A ...
# Processing 1wl7A ...
# Processing 2rcbA ...
# Processing 3ndyC ...
# Processing 7jmrA ...
# Processing 5fzoA ...
# Processing 4bq1A ...
# Processing 3w37A ...
# Processing 7p32AAA ...
# Processing 5d3dA ...
# Processing 6geuA ...
# Processing 4eivA ...
# Processing 1b8pA ...
# Processing 2wmlA ...
# Processing 2w91A ...
# Processing 4yntA ...
# Processing 6xutA ...
# Processing 5i5iB ...
# Processing 2j18A ...
# Processing 4r2kA ...
# Processing 4z3iA ...
# Processing 3r6bA ...
# Processing 2ddxA ...
# Processing 4h5uC ...
# Processing 5y29A ...
# Processing 5f1yA ...
# Processing 3n8tA ...
# Processing 3ur8B ...
# Processing 2d5lA ...
# Processing 7o4qC ...
# Processing 4obxD ...
# Processing 8vr3A ...
# Processing 4yzpA ...
# Processing 1e89A ...
# Processing 1y9uA ...
# Processing 4kyqA ...
# Processing 4my4A ...
# Processing 5m0xA ...
# Processing 5ufyA ...
# Processing 6t8iA ...
# Processing 4ct8A ...
# Processing 7w13A ...
# Processing 7nl3A ...
# Processing 6rzqB ...
# Processing 2engA ...
# Processing 7cedD ...
# Processing 5jijA ...
# Processing 5dzgA ...
# Processing 5fscA ...
# Processing 7ci0B ...
# Processing 3bubA ...
# Processing 3i4xB ...
# Processing 3k8kA ...
# Processing 2pwhB ...
# Processing 3aj7A ...
# Processing 4rjzA ...
# Processing 5xj6A ...
# Processing 6czkA ...
# Processing 2actA ...
# Processing 8jbzAAA ...
# Processing 1gcyA ...
# Processing 1h9kA ...
# Processing 1naaB ...
# Processing 5ngkB ...
# Processing 3zw0B ...
# Processing 4jbnB ...
# Processing 6kghA ...
# Processing 8iw8A ...
# Processing 8qd1B ...
# Processing 3vztX ...
# Processing 5pwdB ...
# Processing 6zisA ...
# Processing 6eguB ...
# Processing 3lrfA ...
# Processing 6rw0A ...
# Processing 1oe4B ...
# Processing 5rw1A ...
# Processing 7p4dAAA ...
# Processing 1j0mA ...
# Processing 6n7qA ...
# Processing 6f7dA ...
# Processing 6w4qF ...
# Processing 3a04A ...
# Processing 3n11A ...
# Processing 5itwB ...
# Processing 5x8hB ...
# Processing 4avyA ...
# Processing 7krkB ...
# Processing 4x54A ...
# Processing 4cr8C ...
# Processing 4g26A ...
# Processing 2vnrA ...
# Processing 3zssB ...
# Processing 1o8pA ...
# Processing 7f81A ...
# Processing 1i04A ...
# Processing 7w1cA ...
# Processing 3wsuA ...
# Processing 8bqcA ...
# Processing 5h41A ...
# Processing 4x1cK ...
# Processing 5avhA ...
# Processing 8ya6A ...
# Processing 1a0sP ...
# Processing 3jugA ...
# Processing 6mgjC ...
# Processing 8p0cB ...
# Processing 4w84A ...
# Processing 4w8aA ...
# Processing 1qtrA ...
# Processing 3w35A ...
# Processing 3w5mA ...
# Processing 3lsxA ...
# Processing 3pzgA ...
# Processing 1b31A ...
# Processing 2ghrA ...
# Processing 1qohL ...
# Processing 5mqnA ...
# Processing 5hwtA ...
# Processing 3ngxA ...
# Processing 5huxA ...
# Processing 5jh1A ...
# Processing 3itaC ...
# Processing 3k4pA ...
# Processing 3rssA ...
# Processing 1bqcA ...
# Processing 7y50A ...
# Processing 5lq5A ...
# Processing 2hrwA ...
# Processing 3c9zA ...
# Processing 1wu4A ...
# Processing 1h12A ...
# Processing 2bv9A ...
# Processing 5b2cA ...
# Processing 6ry0A ...
# Processing 4mgsA ...
# Processing 5hmbA ...
# Processing 3ga9S ...
# Processing 8oseA ...
# Processing 2z8dB ...
# Processing 3eo0B ...
# Processing 3wl6A ...
# Processing 6phuA ...
# Processing 1ujqD ...
# Processing 4j7mA ...
# Processing 1vgyB ...
# Processing 6g3dA ...
# Processing 7bwbA ...
# Processing 3sc7X ...
# Processing 4ffhD ...
# Processing 5kwvA ...
# Processing 2xvpA ...
# Processing 2xvpB ...
# Processing 2ri0A ...
# Processing 6ru1A ...
# Processing 8p6mA ...
# Processing 7pmoG ...
# Processing 1e6pA ...
# Processing 1xxxF ...
# Processing 2wj3C ...
# Processing 5o0sA ...
# Processing 2uveB ...
# Processing 4ykiA ...
# Processing 1o66E ...
# Processing 4rf6B ...
# Processing 4j7rB ...
# Processing 4s1fI ...
# Processing 1sixA ...
# Processing 4k79A ...
# Processing 1arbA ...
# Processing 2silA ...
# Processing 5uq6A ...
# Processing 4ij5B ...
# Processing 1m4vA ...
# Processing 1qnpA ...
# Processing 5c9iC ...
# Processing 1j83A ...
# Processing 4n0hA ...
# Processing 6ehcB ...
# Processing 5o79A ...
# Processing 7plsA ...
# Processing 7z97A ...
# Processing 1wndA ...
# Processing 3etfD ...
# Processing 2y51B ...
# Processing 1vjuB ...
# Processing 1lmnA ...
# Processing 1apyB ...
# Processing 1gutB ...
# Processing 5z2dA ...
# Processing 3l84A ...
# Processing 6f3pA ...
# Processing 6f3pC ...
# Processing 3wnkA ...
# Processing 6sjnB ...
# Processing 4l6xA ...
# Processing 7ky1A ...
# Processing 4bqeA ...
# Processing 3mm3A ...
# Processing 5z73B ...
# Processing 3mwpC ...
# Processing 7v4zF ...
# Processing 4o6nA ...
# Processing 4eu3A ...
# Processing 1n7oA ...
# Processing 4lo8C ...
# Processing 2o9pA ...
# Processing 3scnA ...
# Processing 4iplB ...
# Processing 2x1jA ...
# Processing 4lqrA ...
# Processing 6q62D ...
# Processing 3fw6A ...
# Processing 2jjfA ...
# Processing 6rgjA ...
# Processing 2cdpC ...
# Processing 6kxnB ...
# Processing 3g6lA ...
# Processing 2inuC ...
# Processing 4ggjA ...
# Processing 5o9yA ...
# Processing 1h09A ...
# Processing 3ju4A ...
# Processing 7w1kA ...
# Processing 5logA ...
# Processing 6h20A ...
# Processing 5qr1B ...
# Processing 4f9vB ...
# Processing 3gbzA ...
# Processing 3o0vA ...
# Processing 1s9rB ...
# Processing 6y3aA ...
# Processing 1hkhA ...
# Processing 1mj5A ...
# Processing 4batA ...
# Processing 6wmvC ...
# Processing 3amkA ...
# Processing 5gqwA ...
# Processing 5hq4A ...
# Processing 5yrhB ...
# Processing 2o7iA ...
# Processing 2pvzB ...
# Processing 7yn2B ...
# Processing 3bu9A ...
# Processing 7dqtA ...
# Processing 5fruA ...
# Processing 5jp5B ...
# Processing 6e0oA ...
# Processing 4f0rA ...
# Processing 1fy5A ...
# Processing 1g1qB ...
# Processing 1wxiA ...
# Processing 8j3xA ...
# Processing 5gm5C ...
# Processing 2jemB ...
# Processing 7xvrB ...
# Processing 3b00C ...
# Processing 7uliAAA ...
# Processing 6bmqA ...
# Processing 1dypA ...
# Processing 4l9bA ...

# %% [markdown]
# ## Data for CryptoBench was copied from another project
# Check consistency of the copied data with the data from this project

# %%
import csv, os
import numpy as np
import shutil

# run for both modes: 'mutational' and 'configurational'
mode = 'mutational'
path = f'/home/vit/Projects/flexibility-analysis/data/features/frustration/cryptobench-dataset/{mode}'
inconsistency_path = f'/home/vit/Projects/flexibility-analysis/data/features/frustration/cryptobench-dataset/inconsistent-{mode}'
fluctuation_path = '/home/vit/Projects/flexibility-analysis/data/features/fluctuation/cryptobench-dataset/fluctuation'
for directory in os.listdir(path):
    print(f'Processing {directory} ...')
    protein_id = directory.split('.')[0]
    sequence_length = np.load(f'{fluctuation_path}/{protein_id.split("_")[0]}.npy').shape[0]

    if not os.path.exists(f'{path}/{directory}/FrustrationData/{protein_id}.pdb_{mode}_5adens'):
        print(f'Frustration data not found for {protein_id}')
        continue

    with open(f'{path}/{directory}/FrustrationData/{protein_id}.pdb_{mode}_5adens') as f:
        reader = csv.reader(f, delimiter=' ')
        # skip header
        next(reader)
        residue_count = 0
        for row in reader:
            residue_count += 1
    if sequence_length != residue_count:
        print(f'Data is inconsistent for {directory}')
        shutil.move(f'{path}/{directory}', f'{inconsistency_path}/{directory}')

# 39 / 773 seem to be inconsistent for the CryptoBench dataset -> need to be omitted during analysis
# Out:
# Processing 1a4uB_B.done ...
# Processing 1a8dA_A.done ...
# Processing 1ad1A_A.done ...
# Processing 1ak1A_A.done ...
# Processing 1aylA_A.done ...
# Frustration data not found for 1aylA_A
# Processing 1b0iA_A.done ...
# Processing 1bfnA_A.done ...
# Processing 1bhsA_A.done ...
# Processing 1byiA_A.done ...
# Processing 1c3kA_A.done ...
# Processing 1cuzA_A.done ...
# Processing 1dc6A_A.done ...
# Data is inconsistent for 1dc6A_A.done
# Processing 1dklA_A.done ...
# Processing 1dpjA_A.done ...
# Data is inconsistent for 1dpjA_A.done
# Processing 1dqzA_A.done ...
# Processing 1dteA_A.done ...
# Processing 1e3gA_A.done ...
# Processing 1e5lB_B.done ...
# Processing 1eccB_B.done ...
# Processing 1efhB_B.done ...
# Processing 1eswA_A.done ...
# Processing 1ezlC_C.done ...
# Processing 1f47B_B.done ...
# Processing 1f8aB_B.done ...
# Processing 1fd9A_A.done ...
# Processing 1fdpA_A.done ...
# Frustration data not found for 1fdpA_A
# Processing 1ffhA_A.done ...
# Processing 1fvrA_A.done ...
# Processing 1fwkC_C.done ...
# Processing 1g1oA_A.done ...
# Processing 1g1oD_D.done ...
# Processing 1gqnA_A.done ...
# Processing 1gqzA_A.done ...
# Processing 1h3gB_B.done ...
# Processing 1hbqA_A.done ...
# Processing 1hp1A_A.done ...
# Processing 1ht6A_A.done ...
# Processing 1i0rB_B.done ...
# Processing 1iwlA_A.done ...
# Processing 1j8fC_C.done ...
# Processing 1jpmA_A.done ...
# Processing 1k0nA_A.done ...
# Processing 1k1xB_B.done ...
# Processing 1k4kD_D.done ...
# Processing 1k7kA_A.done ...
# Frustration data not found for 1k7kA_A
# Processing 1kg5A_A.done ...
# Processing 1kn9D_D.done ...
# Frustration data not found for 1kn9D_D
# Processing 1ks9A_A.done ...
# Processing 1l0wB_B.done ...
# Processing 1ljuA_A.done ...
# Processing 1lugA_A.done ...
# Frustration data not found for 1lugA_A
# Processing 1lx7A_A.done ...
# Processing 1m1zA_A.done ...
# Processing 1macB_B.done ...
# Processing 1mhnA_A.done ...
# Processing 1ms4B_B.done ...
# Processing 1mufA_A.done ...
# Processing 1mwrA_A.done ...
# Processing 1n05A_A.done ...
# Processing 1nawB_B.done ...
# Processing 1nbfB_B.done ...
# Processing 1nkoA_A.done ...
# Processing 1nn6A_A.done ...
# Processing 1nulB_B.done ...
# Processing 1nwhB_B.done ...
# Frustration data not found for 1nwhB_B
# Processing 1nzoA_A.done ...
# Processing 1o24D_D.done ...
# Frustration data not found for 1o24D_D
# Processing 1o73A_A.done ...
# Processing 1oibB_B.done ...
# Processing 1omxA_A.done ...
# Processing 1os2B_B.done ...
# Processing 1p74A_A.done ...
# Processing 1pt7A_A.done ...
# Processing 1ptaA_A.done ...
# Processing 1px5B_B.done ...
# Processing 1py3C_C.done ...
# Frustration data not found for 1py3C_C
# Processing 1qhtA_A.done ...
# Processing 1qrzC_C.done ...
# Processing 1r8jA_A.done ...
# Processing 1rf5D_D.done ...
# Processing 1rkmA_A.done ...
# Processing 1rq2B_B.done ...
# Processing 1rxdC_C.done ...
# Processing 1s2lC_C.done ...
# Processing 1s8cC_C.done ...
# Processing 1sjsA_A.done ...
# Processing 1sndB_B.done ...
# Processing 1sulA_A.done ...
# Processing 1t8tA_A.done ...
# Processing 1t9rA_A.done ...
# Processing 1thvA_A.done ...
# Processing 1tplB_B.done ...
# Processing 1tqdA_A.done ...
# Processing 1tqnA_A.done ...
# Processing 1u4pA_A.done ...
# Processing 1uiuA_A.done ...
# Processing 1un1B_B.done ...
# Processing 1urpC_C.done ...
# Processing 1vjuB_B.done ...
# Processing 1vk4A_A.done ...
# Processing 1vr2A_A.done ...
# Processing 1vr6D_D.done ...
# Frustration data not found for 1vr6D_D
# Processing 1wamA_A.done ...
# Processing 1wjgA_A.done ...
# Processing 1wxeA_A.done ...
# Processing 1wycA_A.done ...
# Processing 1x0mA_A.done ...
# Processing 1xqzA_A.done ...
# Processing 1y6iA_A.done ...
# Processing 1yhvA_A.done ...
# Processing 1yl5B_B.done ...
# Data is inconsistent for 1yl5B_B.done
# Processing 1ys0A_A.done ...
# Processing 1z7gD_D.done ...
# Processing 1z90B_B.done ...
# Processing 2a88A_A.done ...
# Processing 2airH_H.done ...
# Processing 2akrA_A.done ...
# Processing 2b0jA_A.done ...
# Processing 2b23B_B.done ...
# Processing 2b3sA_A.done ...
# Processing 2b3sB_B.done ...
# Processing 2b7cA_A.done ...
# Processing 2beiB_B.done ...
# Processing 2bivB_B.done ...
# Processing 2bvaA_A.done ...
# Processing 2by3A_A.done ...
# Processing 2c3vA_A.done ...
# Processing 2c6gA_A.done ...
# Frustration data not found for 2c6gA_A
# Processing 2camA_A.done ...
# Processing 2ci4A_A.done ...
# Processing 2ckqB_B.done ...
# Processing 2cl3A_A.done ...
# Processing 2d0tB_B.done ...
# Processing 2dh4B_B.done ...
# Processing 2e1cA_A.done ...
# Processing 2e2oA_A.done ...
# Processing 2e3kB_B.done ...
# Processing 2e3mA_A.done ...
# Processing 2e64B_B.done ...
# Processing 2e8yA_A.done ...
# Processing 2eplX_X.done ...
# Processing 2exxB_B.done ...
# Processing 2ffyA_A.done ...
# Processing 2fimA_A.done ...
# Processing 2fjyA_A.done ...
# Processing 2fk7A_A.done ...
# Processing 2fn9A_A.done ...
# Processing 2fp1A_A.done ...
# Processing 2frsB_B.done ...
# Processing 2fyuD_D.done ...
# Processing 2g5lA_A.done ...
# Processing 2gcbA_A.done ...
# Processing 2gmeB_B.done ...
# Frustration data not found for 2gmeB_B
# Processing 2gzrA_A.done ...
# Processing 2h6dA_A.done ...
# Processing 2h7gX_X.done ...
# Processing 2h98B_B.done ...
# Processing 2he7A_A.done ...
# Processing 2heuC_C.done ...
# Processing 2hf0A_A.done ...
# Processing 2higA_A.done ...
# Processing 2hq8B_B.done ...
# Processing 2hyyA_A.done ...
# Processing 2i1wB_B.done ...
# Processing 2i6aB_B.done ...
# Processing 2j5iJ_J.done ...
# Processing 2jdwA_A.done ...
# Processing 2jfpA_A.done ...
# Processing 2jfyB_B.done ...
# Processing 2jgvC_C.done ...
# Processing 2jlqA_A.done ...
# Processing 2nvpA_A.done ...
# Processing 2nxjA_A.done ...
# Processing 2o8yA_A.done ...
# Processing 2oa6B_B.done ...
# Processing 2ofmX_X.done ...
# Processing 2oquA_A.done ...
# Processing 2po4A_A.done ...
# Processing 2pryA_A.done ...
# Processing 2psfB_B.done ...
# Processing 2pwoB_B.done ...
# Processing 2qg5D_D.done ...
# Processing 2qsuA_A.done ...
# Processing 2r57A_A.done ...
# Processing 2rl7A_A.done ...
# Processing 2v8jA_A.done ...
# Processing 2vrkB_B.done ...
# Processing 2w5hA_A.done ...
# Processing 2w6rA_A.done ...
# Processing 2w9tA_A.done ...
# Processing 2wgbA_A.done ...
# Processing 2wvhX_X.done ...
# Processing 2wvyB_B.done ...
# Processing 2x2sA_A.done ...
# Processing 2x36D_D.done ...
# Processing 2x87A_A.done ...
# Processing 2xbpA_A.done ...
# Processing 2xe6A_A.done ...
# Processing 2xq0A_A.done ...
# Processing 2xtpA_A.done ...
# Processing 2xurB_B.done ...
# Processing 2y7aB_B.done ...
# Processing 2yd5A_A.done ...
# Frustration data not found for 2yd5A_A
# Processing 2yjrA_A.done ...
# Processing 2ywbA_A.done ...
# Processing 2yygA_A.done ...
# Processing 2yz7C_C.done ...
# Processing 2yzgC_C.done ...
# Processing 2z15B_B.done ...
# Processing 2z6wB_B.done ...
# Processing 2zcoA_A.done ...
# Processing 2zguA_A.done ...
# Processing 2zsuB_B.done ...
# Processing 2zvyA_A.done ...
# Processing 3a06B_B.done ...
# Processing 3a7gA_A.done ...
# Processing 3aarA_A.done ...
# Frustration data not found for 3aarA_A
# Processing 3asyA_A.done ...
# Processing 3b49A_A.done ...
# Processing 3b7wA_A.done ...
# Processing 3bifA_A.done ...
# Processing 3bl7B_B.done ...
# Processing 3bljB_B.done ...
# Processing 3bn9A_A.done ...
# Data is inconsistent for 3bn9A_A.done
# Processing 3brkX_X.done ...
# Frustration data not found for 3brkX_X
# Processing 3bv9B_B.done ...
# Data is inconsistent for 3bv9B_B.done
# Processing 3cabA_A.done ...
# Processing 3chfB_B.done ...
# Processing 3cj1A_A.done ...
# Processing 3cjjA_A.done ...
# Processing 3cvmB_B.done ...
# Processing 3d0rB_B.done ...
# Processing 3db3A_A.done ...
# Processing 3dfaA_A.done ...
# Processing 3dfjA_A.done ...
# Processing 3dlmA_A.done ...
# Frustration data not found for 3dlmA_A
# Processing 3dpcB_B.done ...
# Processing 3e9pA_A.done ...
# Processing 3eomD_D.done ...
# Processing 3f0fB_B.done ...
# Processing 3f99A_A.done ...
# Processing 3f9fA_A.done ...
# Processing 3ffeA_A.done ...
# Processing 3fixB_B.done ...
# Processing 3fq8A_A.done ...
# Processing 3futA_A.done ...
# Processing 3g56B_B.done ...
# Processing 3g8aA_A.done ...
# Processing 3garA_A.done ...
# Processing 3gl0C_C.done ...
# Processing 3h11B_B.done ...
# Processing 3hi6A_A.done ...
# Processing 3hsjA_A.done ...
# Processing 3iecB_B.done ...
# Processing 3ih2A_A.done ...
# Frustration data not found for 3ih2A_A
# Processing 3ikwA_A.done ...
# Processing 3iunA_A.done ...
# Processing 3jxsC_C.done ...
# Processing 3kjeA_A.done ...
# Processing 3l15A_A.done ...
# Processing 3lckA_A.done ...
# Processing 3lo7A_A.done ...
# Processing 3me0A_A.done ...
# Processing 3mo4A_A.done ...
# Processing 3mo7A_A.done ...
# Processing 3mp4D_D.done ...
# Processing 3mwkA_A.done ...
# Processing 3n2wB_B.done ...
# Processing 3naqA_A.done ...
# Processing 3naxA_A.done ...
# Processing 3nshB_B.done ...
# Processing 3nsuA_A.done ...
# Processing 3odnA_A.done ...
# Processing 3ofjA_A.done ...
# Processing 3oguA_A.done ...
# Processing 3oicD_D.done ...
# Processing 3oy6U_U.done ...
# Data is inconsistent for 3oy6U_U.done
# Processing 3p08B_B.done ...
# Processing 3p6eA_A.done ...
# Processing 3pgsB_B.done ...
# Processing 3pidA_A.done ...
# Processing 3psgA_A.done ...
# Frustration data not found for 3psgA_A
# Processing 3px7A_A.done ...
# Processing 3q6uA_A.done ...
# Processing 3qasA_A.done ...
# Processing 3qr9B_B.done ...
# Processing 3qwaB_B.done ...
# Processing 3qwdJ_J.done ...
# Processing 3r5sA_A.done ...
# Processing 3rbhA_A.done ...
# Processing 3rj3F_F.done ...
# Processing 3rwoB_B.done ...
# Processing 3s6wA_A.done ...
# Processing 3sr3A_A.done ...
# Processing 3ssxR_R.done ...
# Processing 3tpeA_A.done ...
# Processing 3u49A_A.done ...
# Processing 3u6kA_A.done ...
# Processing 3umiA_A.done ...
# Processing 3vc7B_B.done ...
# Processing 3vdmB_B.done ...
# Processing 3vhoB_B.done ...
# Data is inconsistent for 3vhoB_B.done
# Processing 3viaB_B.done ...
# Processing 3vjbD_D.done ...
# Processing 3vjzA_A.done ...
# Processing 3vskB_B.done ...
# Processing 3vu2B_B.done ...
# Processing 3vw1A_A.done ...
# Processing 3vzcA_A.done ...
# Processing 3w59D_D.done ...
# Processing 3wdwA_A.done ...
# Processing 3wmgA_A.done ...
# Processing 3wxlD_D.done ...
# Processing 3x13A_A.done ...
# Processing 3zhzB_B.done ...
# Processing 4a6pA_A.done ...
# Processing 4aalA_A.done ...
# Processing 4akdA_A.done ...
# Processing 4brrE_E.done ...
# Processing 4by5B_B.done ...
# Processing 4c6bA_A.done ...
# Processing 4d1nA_A.done ...
# Processing 4d2oB_B.done ...
# Data is inconsistent for 4d2oB_B.done
# Processing 4d8lA_A.done ...
# Processing 4dmzB_B.done ...
# Processing 4e00A_A.done ...
# Processing 4ei8A_A.done ...
# Processing 4eizA_A.done ...
# Processing 4eshA_A.done ...
# Processing 4f0iA_A.done ...
# Processing 4f4iB_B.done ...
# Processing 4f5hB_B.done ...
# Processing 4f7dB_B.done ...
# Processing 4gi3A_A.done ...
# Processing 4gojC_C.done ...
# Processing 4goyA_A.done ...
# Processing 4gvrA_A.done ...
# Processing 4hc4A_A.done ...
# Processing 4honB_B.done ...
# Processing 4hr7A_A.done ...
# Processing 4hr7D_D.done ...
# Processing 4hzrA_A.done ...
# Processing 4i36D_D.done ...
# Processing 4i8yA_A.done ...
# Processing 4ianB_B.done ...
# Processing 4iwsA_A.done ...
# Processing 4jmiA_A.done ...
# Frustration data not found for 4jmiA_A
# Processing 4jycC_C.done ...
# Processing 4k76C_C.done ...
# Processing 4k86A_A.done ...
# Processing 4klxA_A.done ...
# Processing 4ku8A_A.done ...
# Processing 4l7kC_C.done ...
# Processing 4la5A_A.done ...
# Processing 4lg4D_D.done ...
# Processing 4ljpA_A.done ...
# Processing 4m23B_B.done ...
# Processing 4m66A_A.done ...
# Processing 4m7pA_A.done ...
# Processing 4mowA_A.done ...
# Processing 4mqeA_A.done ...
# Processing 4mziA_A.done ...
# Processing 4n4aA_A.done ...
# Processing 4n5gB_B.done ...
# Processing 4n8jA_A.done ...
# Processing 4naiA_A.done ...
# Processing 4nb3B_B.done ...
# Processing 4nfcA_A.done ...
# Processing 4ni8D_D.done ...
# Processing 4nogA_A.done ...
# Processing 4nqtA_A.done ...
# Processing 4nqvF_F.done ...
# Processing 4o7dA_A.done ...
# Processing 4os8B_B.done ...
# Processing 4oyzA_A.done ...
# Processing 4pfsB_B.done ...
# Processing 4pntD_D.done ...
# Processing 4pu0B_B.done ...
# Processing 4punA_A.done ...
# Processing 4pwnA_A.done ...
# Processing 4qasA_A.done ...
# Processing 4qc1B_B.done ...
# Processing 4qfkA_A.done ...
# Frustration data not found for 4qfkA_A
# Processing 4r1mC_C.done ...
# Processing 4r40D_D.done ...
# Processing 4r7tC_C.done ...
# Processing 4rf5A_A.done ...
# Processing 4rieB_B.done ...
# Processing 4rjzA_A.done ...
# Processing 4rksA_A.done ...
# Processing 4rpiD_D.done ...
# Processing 4rvsA_A.done ...
# Processing 4tqrA_A.done ...
# Frustration data not found for 4tqrA_A
# Processing 4trmE_E.done ...
# Processing 4tsnA_A.done ...
# Processing 4twiA_A.done ...
# Processing 4tyvA_A.done ...
# Processing 4ud4B_B.done ...
# Processing 4wbhA_A.done ...
# Processing 4wjxA_A.done ...
# Processing 4xbxB_B.done ...
# Processing 4xg2A_A.done ...
# Processing 4xmqB_B.done ...
# Processing 4xrgA_A.done ...
# Processing 4xv1B_B.done ...
# Processing 4xzpA_A.done ...
# Processing 4yajB_B.done ...
# Processing 4ydrA_A.done ...
# Processing 4yegA_A.done ...
# Frustration data not found for 4yegA_A
# Processing 4yt8B_B.done ...
# Processing 4yynA_A.done ...
# Processing 4z49A_A.done ...
# Processing 4z4lA_A.done ...
# Processing 4z7cA_A.done ...
# Processing 4zcsA_A.done ...
# Processing 5a03A_A.done ...
# Processing 5ae0A_A.done ...
# Processing 5ajoA_A.done ...
# Processing 5ar2B_B.done ...
# Processing 5azqA_A.done ...
# Processing 5bcaA_A.done ...
# Processing 5c74A_A.done ...
# Processing 5caaA_A.done ...
# Processing 5caeB_B.done ...
# Processing 5ck1A_A.done ...
# Processing 5csqA_A.done ...
# Processing 5ct4B_B.done ...
# Processing 5cxgD_D.done ...
# Frustration data not found for 5cxgD_D
# Processing 5cxyB_B.done ...
# Processing 5d27A_A.done ...
# Processing 5dcwA_A.done ...
# Processing 5ddtB_B.done ...
# Processing 5demA_A.done ...
# Processing 5dovB_B.done ...
# Processing 5duoC_C.done ...
# Processing 5dv9A_A.done ...
# Processing 5dzpB_B.done ...
# Processing 5ed0C_C.done ...
# Processing 5ellB_B.done ...
# Processing 5eo7A_A.done ...
# Processing 5f12A_A.done ...
# Processing 5f2mD_D.done ...
# Processing 5f3kB_B.done ...
# Processing 5f46A_A.done ...
# Processing 5f5jA_A.done ...
# Processing 5f7qC_C.done ...
# Processing 5fioB_B.done ...
# Processing 5fsuB_B.done ...
# Processing 5ftkA_A.done ...
# Processing 5ggcA_A.done ...
# Processing 5ggsZ_Z.done ...
# Processing 5gizB_B.done ...
# Processing 5gl7A_A.done ...
# Processing 5gmoA_A.done ...
# Processing 5gw7B_B.done ...
# Processing 5h9kA_A.done ...
# Processing 5hgxA_A.done ...
# Processing 5hi5B_B.done ...
# Processing 5hkeB_B.done ...
# Processing 5hq8A_A.done ...
# Processing 5hsmA_A.done ...
# Processing 5i59A_A.done ...
# Processing 5i5dD_D.done ...
# Processing 5icsC_C.done ...
# Processing 5ihbA_A.done ...
# Processing 5ilkA_A.done ...
# Processing 5ioxA_A.done ...
# Processing 5jhtA_A.done ...
# Processing 5k3aA_A.done ...
# Processing 5k7kA_A.done ...
# Processing 5kopD_D.done ...
# Processing 5l02B_B.done ...
# Processing 5l45A_A.done ...
# Processing 5lccA_A.done ...
# Processing 5lgrB_B.done ...
# Processing 5lorB_B.done ...
# Processing 5lqjC_C.done ...
# Processing 5lsoA_A.done ...
# Processing 5lxhB_B.done ...
# Processing 5mbtC_C.done ...
# Frustration data not found for 5mbtC_C
# Processing 5mcaA_A.done ...
# Processing 5mkbB_B.done ...
# Processing 5nchB_B.done ...
# Processing 5niaA_A.done ...
# Processing 5ninB_B.done ...
# Processing 5nr9B_B.done ...
# Processing 5ny2A_A.done ...
# Processing 5nz1G_G.done ...
# Processing 5nzmA_A.done ...
# Processing 5nzxA_A.done ...
# Processing 5o1mA_A.done ...
# Processing 5ojxA_A.done ...
# Processing 5op0B_B.done ...
# Processing 5rarB_B.done ...
# Processing 5t2vA_A.done ...
# Processing 5t7tA_A.done ...
# Processing 5th0E_E.done ...
# Data is inconsistent for 5th0E_E.done
# Processing 5tqvA_A.done ...
# Processing 5u95B_B.done ...
# Processing 5u9mA_A.done ...
# Processing 5u9mC_C.done ...
# Processing 5un3A_A.done ...
# Processing 5uzvZ_Z.done ...
# Processing 5v1yC_C.done ...
# Processing 5v2kB_B.done ...
# Processing 5v49A_A.done ...
# Processing 5w5dF_F.done ...
# Processing 5wm0A_A.done ...
# Processing 5x1oB_B.done ...
# Processing 5xcwX_X.done ...
# Processing 5xvvE_E.done ...
# Processing 5z0aB_B.done ...
# Processing 5z43A_A.done ...
# Processing 5z67A_A.done ...
# Processing 5z6cA_A.done ...
# Processing 5za4A_A.done ...
# Processing 5ze7B_B.done ...
# Processing 5zicB_B.done ...
# Processing 5zrnB_B.done ...
# Processing 5zv0A_A.done ...
# Processing 6a45B_B.done ...
# Frustration data not found for 6a45B_B
# Processing 6aa3A_A.done ...
# Processing 6aceA_A.done ...
# Processing 6aibA_A.done ...
# Processing 6aqeB_B.done ...
# Processing 6bn5B_B.done ...
# Processing 6bziC_C.done ...
# Processing 6c4gA_A.done ...
# Processing 6c4tA_A.done ...
# Processing 6cfsA_A.done ...
# Processing 6cjfA_A.done ...
# Processing 6co1F_F.done ...
# Processing 6cswC_C.done ...
# Processing 6cwmA_A.done ...
# Processing 6cwwB_B.done ...
# Processing 6cy1A_A.done ...
# Processing 6czpB_B.done ...
# Processing 6dauE_E.done ...
# Processing 6ddlB_B.done ...
# Processing 6dtrA_A.done ...
# Processing 6dz8A_A.done ...
# Processing 6eifB_B.done ...
# Processing 6esnA_A.done ...
# Processing 6ezrA_A.done ...
# Processing 6f4mA_A.done ...
# Processing 6f56B_B.done ...
# Processing 6fp0A_A.done ...
# Processing 6g80B_B.done ...
# Processing 6g9zA_A.done ...
# Processing 6gsoC_C.done ...
# Processing 6h1oB_B.done ...
# Processing 6h6kA_A.done ...
# Processing 6herA_A.done ...
# Processing 6hl0A_A.done ...
# Processing 6hr4A_A.done ...
# Processing 6hrvA_A.done ...
# Processing 6i1sA_A.done ...
# Processing 6i5gB_B.done ...
# Processing 6ih8C_C.done ...
# Processing 6infA_A.done ...
# Processing 6irxA_A.done ...
# Processing 6iu0B_B.done ...
# Processing 6iz9A_A.done ...
# Processing 6j1hA_A.done ...
# Processing 6jakC_C.done ...
# Processing 6jhmD_D.done ...
# Processing 6jnjA_A.done ...
# Processing 6jp2A_A.done ...
# Processing 6ksuA_A.done ...
# Processing 6kx4A_A.done ...
# Processing 6kyqA_A.done ...
# Processing 6l1iB_B.done ...
# Processing 6l61A_A.done ...
# Processing 6lioB_B.done ...
# Processing 6llgA_A.done ...
# Processing 6ltfA_A.done ...
# Processing 6m9aA_A.done ...
# Processing 6mkxA_A.done ...
# Processing 6n95D_D.done ...
# Processing 6nflA_A.done ...
# Processing 6oahF_F.done ...
# Processing 6opbD_D.done ...
# Processing 6owyA_A.done ...
# Processing 6p5bC_C.done ...
# Frustration data not found for 6p5bC_C
# Processing 6pj6U_U.done ...
# Processing 6pk5A_A.done ...
# Processing 6plfB_B.done ...
# Processing 6pntA_A.done ...
# Processing 6puvA_A.done ...
# Processing 6pvgA_A.done ...
# Processing 6q6jA_A.done ...
# Processing 6q7qA_A.done ...
# Processing 6q8zD_D.done ...
# Processing 6qb5D_D.done ...
# Processing 6qflA_A.done ...
# Processing 6qlbC_C.done ...
# Processing 6qpeA_A.done ...
# Processing 6rwdA_A.done ...
# Processing 6rxdA_A.done ...
# Processing 6s3pA_A.done ...
# Processing 6slkC_C.done ...
# Processing 6suiA_A.done ...
# Processing 6sz4A_A.done ...
# Processing 6tbtB_B.done ...
# Processing 6tn3A_A.done ...
# Processing 6u9cA_A.done ...
# Processing 6up2A_A.done ...
# Processing 6ur2A_A.done ...
# Processing 6uw3A_A.done ...
# Processing 6vtgC_C.done ...
# Processing 6w3cC_C.done ...
# Processing 6x41B_B.done ...
# Processing 6x84A_A.done ...
# Processing 6xl4C_C.done ...
# Processing 6xqxB_B.done ...
# Frustration data not found for 6xqxB_B
# Processing 6xueA_A.done ...
# Processing 6ydkA_A.done ...
# Processing 6z2hB_B.done ...
# Processing 6z6zA_A.done ...
# Processing 6zdcA_A.done ...
# Processing 7aa2B_B.done ...
# Processing 7alfA_A.done ...
# Processing 7aqbB_B.done ...
# Processing 7autA_A.done ...
# Processing 7av9AAA_A.done ...
# Processing 7b6qA_A.done ...
# Processing 7bhjA_A.done ...
# Processing 7bn2BBB_B.done ...
# Processing 7bp1B_B.done ...
# Processing 7btcB_B.done ...
# Processing 7c1uA_A.done ...
# Processing 7cehA_A.done ...
# Processing 7ciuA_A.done ...
# Processing 7cluA_A.done ...
# Processing 7crmC_C.done ...
# Processing 7ctdA_A.done ...
# Processing 7cyrA_A.done ...
# Processing 7djnA_A.done ...
# Processing 7ec1B_B.done ...
# Processing 7eguA_A.done ...
# Processing 7ejwD_D.done ...
# Processing 7el8A_A.done ...
# Processing 7eryA_A.done ...
# Processing 7etxA_A.done ...
# Processing 7f0oA_A.done ...
# Processing 7ft3A_A.done ...
# Processing 7g8eB_B.done ...
# Processing 7jhkD_D.done ...
# Processing 7jrbA_A.done ...
# Processing 7js3D_D.done ...
# Processing 7k4wA_A.done ...
# Processing 7kndA_A.done ...
# Processing 7kqlT_T.done ...
# Processing 7l1zB_B.done ...
# Processing 7l5lB_B.done ...
# Processing 7l8qA_A.done ...
# Processing 7lpuA_A.done ...
# Processing 7m2gA_A.done ...
# Processing 7moiB_B.done ...
# Processing 7n6zA_A.done ...
# Processing 7nbzB_B.done ...
# Processing 7nteB_B.done ...
# Processing 7oppC_C.done ...
# Processing 7oueA_A.done ...
# Processing 7p75AAA_A.done ...
# Processing 7pa0B_B.done ...
# Processing 7pizC_C.done ...
# Frustration data not found for 7pizC_C
# Processing 7pldB_B.done ...
# Processing 7psjA_A.done ...
# Processing 7qluA_A.done ...
# Processing 7qniAAA_A.done ...
# Processing 7r00AAA_A.done ...
# Processing 7r51B_B.done ...
# Processing 7rawA_A.done ...
# Processing 7rx7A_A.done ...
# Processing 7s2nA_A.done ...
# Processing 7s5gA_A.done ...
# Processing 7se6A_A.done ...
# Processing 7sfgA_A.done ...
# Processing 7sktB_B.done ...
# Processing 7so5A_A.done ...
# Processing 7t4zB_B.done ...
# Processing 7ujrA_A.done ...
# Processing 7uvwN_N.done ...
# Processing 7vdaA_A.done ...
# Processing 7vtzA_A.done ...
# Processing 7vvvA_A.done ...
# Processing 7wmyA_A.done ...
# Processing 7xznC_C.done ...
# Processing 7ymfA_A.done ...
# Processing 7yv0A_A.done ...
# Processing 7ywjA_A.done ...
# Processing 7yx7A_A.done ...
# Processing 7zzxB_B.done ...
# Processing 8a74A_A.done ...
# Processing 8abuB_B.done ...
# Processing 8azbA_A.done ...
# Processing 8bbcA_A.done ...
# Processing 8bdiI_I.done ...
# Processing 8bp9BBB_B.done ...
# Processing 8c3uA_A.done ...
# Processing 8cfbC_C.done ...
# Processing 8cn8C_C.done ...
# Processing 8cqlB_B.done ...
# Processing 8dfnA_A.done ...
# Processing 8dfnB_B.done ...
# Processing 8e1jB_B.done ...
# Processing 8elmA_A.done ...
# Processing 8evvA_A.done ...
# Processing 8ezsB_B.done ...
# Processing 8fmuB_B.done ...
# Processing 8g25H_H.done ...
# Processing 8ghcB_B.done ...
# Processing 8gw3A_A.done ...
# Processing 8h0nB_B.done ...
# Frustration data not found for 8h0nB_B
# Processing 8h6pA_A.done ...
# Processing 8hs6H_H.done ...
# Processing 8i7xC_C.done ...
# Processing 8ixpA_A.done ...
# Processing 8jisR_R.done ...
# Processing 8jqkA_A.done ...
# Processing 8ogrB_B.done ...
# Processing 8oqpC_C.done ...
# Processing 8pfpA_A.done ...
# Processing 8pzmA_A.done ...
# Data is inconsistent for 8pzmA_A.done
# Processing 8r43A_A.done ...
# Processing 8s32A_A.done ...
# Processing 8sc0A_A.done ...
# Processing 8slbA_A.done ...
# Processing 8sxwA_A.done ...
# Processing 8t2lA_A.done ...
# Processing 8vdyA_A.done ...
# Frustration data not found for 8vdyA_A
# Processing 8wl5A_A.done ...
# Processing 9bhrB_B.done ...
